// %%
var input = """467..114..
...*......
..35..633.
......#...
617*......
.....+.58.
..592.....
......755.
...$.*....
.664.598..""".lines()


val symbols: List<Char> = listOf('*', '#', '$', '+');


val result = input.mapIndexed({ row, line ->
    line.mapIndexed({ col, c -> 
        if (symbols.contains(c)) {
            Pair(col, row)
        } else {
            null
        }
    }).filterNotNull()
    
}).filter {it.isNotEmpty()}.flatten()

result
// Out:
// [(3, 1), (6, 3), (3, 4), (5, 5), (3, 8), (5, 8)]

// %%
setOf("a", "b").intersect(setOf("c", "a"))
// Out:
// [a]

// %%
import java.util.regex.Pattern

"1 2 3 4   45 6".split(Pattern.compile("(\\s)+"))
// Out:
// [1, 2, 3, 4, 45, 6]

// %%
import java.util.regex.Pattern

"Card 1: 41 48 83 86 17 | 83 86  6 31 17  9 48 53".split(":").get(1)
                .split("|").get(1)
                .split(Pattern.compile("(\\s)+"))
    .filter { it.isNotEmpty() }
                .map {it.toInt()}
// Out:
// [83, 86, 6, 31, 17, 9, 48, 53]

// %%
"2844655470".toLong()
// Out:
// 2844655470
